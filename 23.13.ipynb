# %%
import folium
from folium import plugins
import branca

m = folium.Map(location=[10.776, 106.701], zoom_start=15)

nhom_giao_duc = folium.FeatureGroup('Cơ sở Giáo dục')
nhom_y_te = folium.FeatureGroup('Cơ sở Y tế')
nhom_thuong_mai = folium.FeatureGroup('Trung tâm Thương mại')
vung_dich_vu = folium.FeatureGroup('Vùng dịch vụ ưu tiên')

folium.Marker([10.7751, 106.6974], popup='THPT Chuyên Trần Đại Nghĩa', tooltip='Chi tiết').add_to(nhom_giao_duc)
folium.Marker([10.7831, 106.7003], popup='Trường ĐH Khoa học Xã hội và Nhân văn', tooltip='Chi tiết').add_to(nhom_giao_duc)

folium.Marker([10.7792, 106.6994], popup='Bệnh viện Nhi Đồng 2', tooltip='Chi tiết').add_to(nhom_y_te)
folium.Marker([10.7850, 106.7052], popup='Bệnh viện Đa khoa Sài Gòn', tooltip='Chi tiết').add_to(nhom_y_te)

folium.Marker([10.7741, 106.7012], popup='Vincom Center Đồng Khởi', tooltip='Chi tiết').add_to(nhom_thuong_mai)
folium.Marker([10.7719, 106.7005], popup='Takashimaya Việt Nam', tooltip='Chi tiết').add_to(nhom_thuong_mai)

nhom_giao_duc.add_to(m)
nhom_y_te.add_to(m)
nhom_thuong_mai.add_to(m)
vung_dich_vu.add_to(m)

folium.LayerControl().add_to(m)

folium.Circle(
    location=(10.777, 106.6953),
    radius=1000,
    color='green',
    fill=True,
    fill_opacity=0.15,
    popup='Khu vực hỗ trợ giao hàng nhanh'
).add_to(vung_dich_vu)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
